# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeHarris-AHAM/LeetchCode/blob/main/Rotate%20Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Rotate Image
#
# You are given an n x n 2D matrix representing an image, rotate the image by 90 degrees (clockwise).
#
# You have to rotate the image in-place, which means you have to modify the input 2D matrix directly. DO NOT allocate another 2D matrix and do the rotation.
#
# Assume the environment does not allow you to store 64-bit integers (signed or unsigned).
#
# Example 1:
#
#
# ```
# Input: matrix = [[1,2,3],[4,5,6],[7,8,9]]
# Output: [[7,4,1],[8,5,2],[9,6,3]]
# ```
# ![image.png](data:image/png;base64,...)
#
# Example 2:
#
# ![image.png](data:image/png;base64,...)
# ```
# Input: matrix = [[5,1,9,11],[2,4,8,10],[13,3,6,7],[15,14,12,16]]
# Output: [[15,13,2,5],[14,3,4,1],[12,6,8,9],[16,7,10,11]]
# ```
#
#
#
# ## Constraints:
#
#
# n == matrix.length == matrix[i].length
#
# 1 <= n <= 20
#
# -1000 <= matrix[i][j] <= 1000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def RotateImage(matrix):
    N = len(matrix)   
    temp = 0
    for x in range(0, int(N/2)):
          for y in range(x, N - x - 1):
            temp = matrix[x][y]
            matrix[x][y] = matrix[N - 1 - y][x]
            matrix[N - 1 - y][x] = matrix[N - 1 - x][N - 1 - y]
            matrix[N - 1 - x][N - 1 - y] = matrix[y][N - 1 - x]
            matrix[y][N - 1 - x] = temp  
    return matrix

# Example 1
matrix = [[1,2,3],[4,5,6],[7,8,9]]
print(RotateImage(matrix))
# Example 2
matrix = [[5,1,9,11],[2,4,8,10],[13,3,6,7],[15,14,12,16]]
print(RotateImage(matrix))
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]
# [[15, 13, 2, 5], [14, 3, 4, 1], [12, 6, 8, 9], [16, 7, 10, 11]]

# %% [markdown]
# ##Runtime
# 285 ms, faster than 5.41% of Python3 online submissions for Rotate Image.
#
# ##Memory Usage
# 31.9 MB, less than 30.03% of Python3 online submissions for Rotate Image.
